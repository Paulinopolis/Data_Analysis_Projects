# %%
import requests
import bs4
from bs4 import BeautifulSoup
from requests_oauthlib import OAuth1   
import pandas as pd
import pymysql
from sqlalchemy import create_engine

auth_params = {
    'app_key':'#APPKEY',
    'app_secret':'#APPKEYSECRET',
    'oauth_token':'#TOKEN',
    'oauth_token_secret':'#TOKENSECRET'}

# Creating an OAuth Client connection
auth = OAuth1(
    auth_params['app_key'],
    auth_params['app_secret'],
    auth_params['oauth_token'],
    auth_params['oauth_token_secret']
)

# %%
import pandas as pd

# %%
# url according to twitter API
url_rest = "https://api.twitter.com/1.1/search/tweets.json"

# getting rid of retweets in the extraction results and filtering all replies to the tweet often uncessary for the analysis
q = '%23lafrancenapasditsonderniermot' # Twitter handle of Amazon India

# count : no of tweets to be retrieved per one call and parameters according to twitter API
params = {'q': q, 'count': 1000, 'lang': 'fr'}
results = requests.get(url_rest, params=params, auth=auth)

results.json 
tweets = results.json()
tweets
tweetData = pd.DataFrame(tweets['statuses']) 
tweetData
# Out:
#                         created_at                   id               id_str  \
# 0   Fri Nov 05 06:26:07 +0000 2021  1456508103277617152  1456508103277617152
# 1   Thu Nov 04 18:35:37 +0000 2021  1456329299934461953  1456329299934461953
# 2   Thu Nov 04 13:09:36 +0000 2021  1456247256772792321  1456247256772792321
# 3   Thu Nov 04 05:50:47 +0000 2021  1456136823974006785  1456136823974006785
# 4   Wed Nov 03 22:34:34 +0000 2021  1456027048347119617  1456027048347119617
# 5   Wed Nov 03 20:30:28 +0000 2021  1455995817316298754  1455995817316298754
# 6   Wed Nov 03 12:16:14 +0000 2021  1455871437080862721  1455871437080862721
# 7   Wed Nov 03 01:11:39 +0000 2021  1455704192706916353  1455704192706916353
# 8   Tue Nov 02 09:30:29 +0000 2021  1455467338145406978  1455467338145406978
# 9   Mon Nov 01 21:10:44 +0000 2021  1455281175656796168  1455281175656796168
# 10  Mon Nov 01 20:48:33 +0000 2021  1455275591142420492  1455275591142420492
# ...

# %%
#Export comma-separated variable file

Tweets = tweetData.to_csv('tweets.csv')
engine = create_engine('mysql+pymysql://root:username,password@localhost/Tweets')
data = pd.read_sql_query('SELECT text FROM Tweets.raw_table', engine)
data
# Out:
#                                                 text
# 0  Deux bourre-pifs, un coup de GHB ou une tourna...
# 1  Nous étions dans un état de sidération devant ...
# 2  RT @PetitPatrioteL: J'ai eu des frjssons en li...
# 3  RT @PetitPatrioteL: J'ai eu des frjssons en li...
# 4  J'ai eu des frjssons en lisant ça : "Le Trump ...
# 5  No comment #lafrancenapasditsonderniermot #zem...
# 6  @ActusNonStop @AlexndraBorchio Suisse Allemagn...

# %%
def remove_url(txt):
    return " ".join(re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', "", txt).split())
all_tweets_no_urls = [remove_url(tweet) for tweet in tweetData]
all_tweets_no_urls

# %%
words_in_tweet = [tweet.lower().split() for tweet in all_tweets_no_urls]
words_in_tweet
# Out:
# [['#onenpeutplus',
#   'zemmour',
#   'president',
#   'vite',
#   '!!!',
#   '#zemmourourien',
#   '#zemmourpresident',
#   '#lafrancenapasditsonderniermot',
#   '🇫🇷✊🔥😡…'],
#  ["j'ai",
#   'eu',
#   'des',
#   'frjssons',
#   'en',
#   'lisant',
#   'ça',
#   ':',
#   '"le',
#   'trump',
#   'français,',
#   "c'est",
#   'vous."',
#   '#zemmour2022',
#   '#lafrancenapasditsonderniermot'],
#  ['@zemmoureric',
#   'c’est',
#   'exactement',
#   'ça.',
#   'comme',
#   'ils',
#   'ne',
#   'peuvent',
#   'pas',
#   'vous',
#   'attaquer',
#   'sur',
#   'le',
#   'fond',
#   '(le',
#   'réel',
#   'est',
#   'têtu),',
#   'ils',
#   'se',
#   'con…'],
#  ['ma',
#   'première',
#   'photo',
#   'd’@zemmoureric',
#   'prise',
#   'à',
#   'la',
#   'conférence',
#   'de',
#   'pleurtuit.#croiseedeschemins…'],
#  ['@zemmoureric', 'merci', 'à', 'vous', '🙏', '#lafrancenapasditsonderniermot'],
#  ['#lafrancenapasditsonderniermot',
#   'de',
#   '@zemmoureric',
#   'fut',
#   'un',
# ...
