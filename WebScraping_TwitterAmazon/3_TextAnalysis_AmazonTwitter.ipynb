# %%
#Import Packages

# %%
pip install mysql-connector

# %%
! pip install nlkt

# %%
pip install wordcloud

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import re
import itertools
import collections

# %%
#Lecture CSV
data_amazon = pd.read_csv('/Users/username/Documents/Week10/text_amazon.csv')
data_twitter = pd.read_csv('/Users/username/Documents/Week10/tweets.csv')

# %%
#Lecture my SQL Fichier Amazon
engine = create_engine('mysql+pymysql://username:password@localhost/QueryAmazonTwitter')
texto = pd.read_sql_query('SELECT * FROM QueryAmazonTwitter.textamazon', engine)
texto
# Out:
#                                                 Texto  Source
# 0   zemmour a raison zemour a raison sur tout il d...  Amazon
# 1   un livre exceptionnel quel courage, quelle plu...  Amazon
# 2   un excellent ouvrage. a lire absolument. un ex...  Amazon
# 3   livre de l'année 2021 le livre à lire pour cet...  Amazon
# 4   génie incompris cet homme sauvera la france. l...  Amazon
# 5   un livre à lire que l'on partage ou non ses id...  Amazon
# 6   un best seller - je le voudrais en format poch...  Amazon
# 7                                un succès j'adore ez  Amazon
# 8   bon pour le feu... et encore mon barbecue à in...  Amazon
# 9   très bon pq appréciable pour un bon feu ou en ...  Amazon
# 10                                pas mal bon bouquin  Amazon
# 11  très bon livre sur la pêche très bon livre sur...  Amazon
# 12  enfin une grande personne qui a tout compris e...  Amazon
# 13  un livre de fakes news un livre plein de bêtis...  Amazon
# 14  choses tues - un futur président est né. un li...  Amazon
# 15  a eviter absolument pourquoi tant de haine, d'...  Amazon
# 16  a lire absolument ! quelle chance vous avez me...  Amazon
# 17  non consensuel excellent ouvrage a contre cour...  Amazon
# 18  il dérange....tant mieux je viens de le comman...  Amazon
# 19  souffleur de braises il est trop fort ! le thè...  Amazon
# 20  mais quelle horreur... eric zemmour revient to...  Amazon
# 21  très intéressant et très bien écrit une réflex...  Amazon
# 22  très bon allume feu très utile pour raviver la...  Amazon
# 23  ouvrez les yeux toujours les mêmes constats\nl...  Amazon
# 24  zemmour dit trop de mots je viens de terminer ...  Amazon
# 25  un futur best-seller. un livre programme zemmo...  Amazon
# 26       génial zemmour a tout compris à son épouque.  Amazon
# 27  du grand z le z dit et écrit tout haut ce que ...  Amazon
# 28  le trump français ? lu.\n#spoiler\n\n« nous de...  Amazon
# 29  un livre bien écrit mais qui contient beaucoup...  Amazon
# 30  a lire avec attention comme tous ces autres ou...  Amazon
# 31  brillant !!! zemmour démontre les causes du dé...  Amazon
# 32  la bataille va être rude mais zemmour va gagne...  Amazon
# 33  exceptionnel ! un livre a lire absolument. esp...  Amazon
# 34  factuel, et vif comme dans son habitude, il ne...  Amazon
# 35  excellent excellent quelqu un qui ose dire la ...  Amazon
# 36  à lire absolument excellente analyse de notre ...  Amazon
# 37  au secours !!! je l'ai emprunté , "pour voir" ...  Amazon
# 38  l'homme qui attire les belles femmes les premi...  Amazon
# 39  urgence pour la france le z vient de démontrer...  Amazon

# %%
#Lecture my SQL Fichier Twitter
engine = create_engine('mysql+pymysql://username:password@localhost/QueryAmazonTwitter')
twits = pd.read_sql_query('SELECT * FROM QueryAmazonTwitter.tweets', engine)
twits
# Out:
#                                                 Texto   Source
# 0   certe mais c'est son destin français pour que ...  Twitter
# 1   rt @unvola2: cela laisse peu de doute qu’éric ...  Twitter
# 2   rt @unvola2: cela laisse peu de doute qu’éric ...  Twitter
# 3   deux bourre-pifs, un coup de ghb ou une tourna...  Twitter
# 4   rt @unvola2: cela laisse peu de doute qu’éric ...  Twitter
# 5   rt @unvola2: cela laisse peu de doute qu’éric ...  Twitter
# 6   cela laisse peu de doute qu’éric #zemmour se d...  Twitter
# 7   éric #zemmour sera a #bordeaux pour sa #croise...  Twitter
# 8   nous étions dans un état de sidération devant ...  Twitter
# 9   #onenpeutplus zemmour president vite !!! #zemm...  Twitter
# 10  rt @petitpatriotel: j'ai eu des frjssons en li...  Twitter
# 11  rt @petitpatriotel: j'ai eu des frjssons en li...  Twitter
# 12  j'ai eu des frjssons en lisant ça : "le trump ...  Twitter
# 13  @zemmoureric c’est exactement ça. comme ils ne...  Twitter
# 14  rt @thomas_france75: ma première photo d’@zemm...  Twitter
# 15  ma première photo d’@zemmoureric prise à la co...  Twitter
# 16  rt @matthew1_gv: tout le monde a noté ? ??\n#c...  Twitter
# 17  tout le monde a noté ? ??\n#croiseedeschemins\...  Twitter
# 18  @zemmoureric merci à vous ?? #lafrancenapasdit...  Twitter
# 19  #lafrancenapasditsonderniermot de @zemmoureric...  Twitter
# 20  rt @dede_alsace_68: @brevesdepresse la force e...  Twitter
# 21  @brevesdepresse la force est avec nous zemmour...  Twitter
# 22  rt @bichette2157: #lafrancenapasditsondernierm...  Twitter
# 23  rt @bichette2157: #lafrancenapasditsondernierm...  Twitter
# 24  #lafrancenapasditsonderniermot  #albertmichel ...  Twitter
# 25  rt @matthew1_gv: acheté !\n\n#lafrancenapasdit...  Twitter
# 26  rt @matthew1_gv: acheté !\n\n#lafrancenapasdit...  Twitter
# 27  rt @matthew1_gv: acheté !\n\n#lafrancenapasdit...  Twitter
# 28  acheté !\n\n#lafrancenapasditsonderniermot htt...  Twitter
# 29  no comment #lafrancenapasditsonderniermot #zem...  Twitter
# 30  attention j’ouvre #lafrancenapasditsondernierm...  Twitter
# 31  @actusnonstop @alexndraborchio suisse allemagn...  Twitter
# 32  inscrivez-vous pour la #croiseedeschemins d'ér...  Twitter

# %%
#Append tables 
data = texto.append(twits)

# %%
#Extraire la colonne Texto
words = data.Texto

# %%
#Joindre le text de la colonne Texto
w_joined = ' '.join(words)

# %%
#NETTOYAGE Text
#Supprimer URL
def remove_url(txt):
    return " ".join(re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', "", txt).split())
w_cleaned1 = remove_url(w_joined)

# %%
#REMOVE PUNCTUATION

def remove_punc(string):
    punc = '''!()-[]{};:'"\, <>./?$%^&*_~'''
    for ele in string:  
        if ele in punc:  
            string = string.replace(ele, " ") 
    return string
words_new = remove_punc(w_cleaned1)

# %%
#This part is a test to see how do the WordCloud Works. Please do not take it into account.
#from wordcloud import WordCloud, STOPWORDS

#stopwords = set(STOPWORDS)
#print(STOPWORDS)
#for wds in ['http', 'https', 'www', 'fr', 'com', 'io', 'org', 'co', 'jo', 'edu', 'news', 'html', 'htm',\
           # 'github', 'youtube', 'google', 'blog', 'watch', 'de', 'le', 'la', 'en', 'sur', 'vous', 'les', \
           #'ajouter', 'README', 'md', 'et', 'PROCESS', 'CMYK', 'des', 'chargement', 'playlists', 'endobj', \
          # 'obj','est', 'use', 'using', 'will', 'web', 'first','pour', 'du', 'une', 'que']:
    #stopwords.add(wds)

# %%
#word lists with python library
#stop_words = set(stopwords.words('french'))
#list(stop_words)

# %%
#words_in_tweet = [tweet.lower().split() for w in all_tweets_no_punct]

# %%
#all_words_nsw = list(itertools.chain(*words_in_tweet))

# %%
# Create counter of words in clean tweets
#counts_nsw_nc = collections.Counter(words_new)
#nowords = counts_nsw_nc.most_common(100)

# %%
#w_joined.concordance("france")
#print('\n')

# %%
import re, nltk
#Tokenisation naïve sur les espaces entre les mots => on obtient une liste de mots
tokens = re.split('\s+', ' '.join(data['Texto']))

# %%
#On transforme cette liste en objet nltk "Text" (objet chaine de caractère qui conserve la notion de tokens, et qui
#comprend  un certain nombre de méthodes utiles pour explorer les données.
text2 = nltk.Text(tokens)

# %%
#Removing stopwords
#stopword = nltk.corpus.stopwords.words('french')
#def remove_stopwords(text):
    #text3 = [word for word in text2 if word not in stopword]
    #return text3
    
#tw_list['nonstop'] = tw_list['tokenized'].apply(lambda x: remove_stopwords(x))

# %%
## la méthode vocab permet d'obtenir pour chaque terme présent dans la liste text nltk, le nombre d'occurence des termes
## ici on crée le dictionnaire fdist

fdist = text2.vocab()

list(fdist.items())[:100]
# Out:
# [('zemmour', 26),
#  ('a', 20),
#  ('raison', 2),
#  ('zemour', 2),
#  ('sur', 17),
#  ('tout', 17),
#  ('il', 9),
#  ('dit', 9),
#  ('la', 75),
#  ('verite', 1),
#  ('......', 1),
#  ('un', 33),
#  ('livre', 25),
#  ('exceptionnel', 2),
#  ('quel', 1),
#  ('courage,', 1),
#  ('quelle', 3),
#  ('plume', 4),
#  ('!', 17),
#  ('à', 37),
#  ('lire', 12),
#  ('absolument,', 1),
#  ('pour', 26),
#  ('tous', 4),
#  ('ses', 8),
#  ('partisans', 1),
#  ('et', 52),
#  ('surtout', 3),
#  ('détracteurs', 1),
#  ('excellent', 6),
#  ('ouvrage.', 2),
#  ('absolument.', 3),
#  ('eric', 6),
#  ('raconte', 1),
#  ('avec', 7),
#  ('une', 21),
#  ('précision', 1),
#  ('fluidité', 1),
#  ('sans', 5),
#  ('précédent', 1),
#  ("l'histoire", 2),
#  ('de', 84),
#  ('france', 11),
#  ('moderne.', 1),
#  ("j'ai", 9),
#  ('lu', 3),
#  ('les', 28),
#  ('autres', 3),
#  ('livres', 1),
#  ('ce', 19),
#  ('même', 2),
#  ('auteur', 1),
#  ('je', 13),
#  ('ne', 8),
#  ('peux', 1),
#  ("qu'approuver", 1),
#  ('dires.', 1),
#  ('est', 25),
#  ('en', 24),
#  ('danger', 1),
#  ('mort,', 1),
#  ('faut', 2),
#  ('impérativement', 1),
#  ('sauver.', 1),
#  ("l'union", 1),
#  ('fait', 2),
#  ('force.', 1),
#  ('vive', 2),
#  ('monsieur', 3),
#  ('z.', 1),
#  ("l'année", 1),
#  ('2021', 1),
#  ('le', 35),
#  ('cette', 5),
#  ('rentrée', 1),
#  ('septembre', 1),
#  ('2021,', 1),
#  ('éric', 5),
#  ('frappe', 1),
#  ('encore', 5),
#  ('fois', 2),
#  ('très', 11),
#  ('fort.', 1),
#  ('constat', 1),
#  ('lucide', 2),
#  ("l'état", 3),
#  ('notamment', 1),
#  ('dérive', 1),
#  ('tragique', 1),
#  ('ces', 4),
#  ('dernières', 1),
#  ('années.', 1),
#  ('lueur', 1),
#  ("d'espoir", 1),
#  ('cependant,', 1),
#  ("n'a", 6),
#  ('pas', 20),
#  ('son', 18),
#  ('dernier', 4),
#  ('mot.', 4)]

# %%
table = pd.DataFrame(list(fdist.items()),
                   columns=['Words', 'Frequency'])

# %%
table.head(40)
# Out:
#            Words  Frequency
# 0        zemmour         26
# 1              a         20
# 2         raison          2
# 3         zemour          2
# 4            sur         17
# 5           tout         17
# 6             il          9
# 7            dit          9
# 8             la         75
# 9         verite          1
# 10        ......          1
# 11            un         33
# 12         livre         25
# 13  exceptionnel          2
# 14          quel          1
# 15      courage,          1
# 16        quelle          3
# 17         plume          4
# 18             !         17
# 19             à         37
# 20          lire         12
# 21   absolument,          1
# 22          pour         26
# 23          tous          4
# 24           ses          8
# 25     partisans          1
# 26            et         52
# 27       surtout          3
# 28   détracteurs          1
# 29     excellent          6
# 30      ouvrage.          2
# 31   absolument.          3
# 32          eric          6
# 33       raconte          1
# 34          avec          7
# 35           une         21
# 36     précision          1
# 37      fluidité          1
# 38          sans          5
# 39     précédent          1

# %%
data_sorted = table.sort_values(['Frequency'], ascending=False)

# %%
data_sorted.head(30)
# Out:
#                               Words  Frequency
# 41                               de         84
# 8                                la         75
# 26                               et         52
# 19                                à         37
# 72                               le         35
# 11                               un         33
# 152                             qui         28
# 46                              les         28
# 0                           zemmour         26
# 22                             pour         26
# 57                              est         25
# 12                            livre         25
# 58                               en         24
# 35                              une         21
# 1                                 a         20
# 96                              pas         20
# 807  #lafrancenapasditsonderniermot         20
# 108                             que         20
# 49                               ce         19
# 97                              son         18
# 167                            dans         18
# 18                                !         17
# 5                              tout         17
# 4                               sur         17
# 141                              du         17
# 810                              rt         14
# 127                            mais         14
# 52                               je         13
# 118                              on         13
# 170                             des         13

# %%
# Une autre méthode "concordance" : montre les occurences d'un mot dans son contexte
print("Exemples d'occurences du terme 'france' :")
text2.concordance("france")
print('\n')
# Out:
# Exemples d'occurences du terme 'python' :
# Displaying 11 of 11 matches:
# ité sans précédent l'histoire de la france moderne. j'ai lu tous les autres li
#  ne peux qu'approuver ses dires. la france est en danger de mort, il faut impé
# ver. l'union fait la force. vive la france et vive monsieur z. livre de l'anné
# rt. constat lucide sur l'état de la france et notamment la dérive tragique de
# s. une lueur d'espoir cependant, la france n'a pas dit son dernier mot. génie
# uis des décennies et qui ont mis la france dans l'état dans laquelle on la ret
#  de celui qui peut encore sauver la france du chaos qui s’est installé inexora
# uxième génération. effectivement la france n'a pas dit son dernier mot. mais q
#  présentera à la présidentielle. la france en a besoin, et oui, la france n'a
# . la france en a besoin, et oui, la france n'a pas dit son dernier mot. le tru
# t sa vie privée. ;) urgence pour la france le z vient de démontrer une nouvell

# %%
# Une autre méthode "concordance" : montre les occurences d'un mot dans son contexte
print("Exemples d'occurences du terme 'sauver' :")
text2.concordance("sauver")
print('\n')
# Out:
# Exemples d'occurences du terme 'sauver' :
# Displaying 1 of 1 matches:
# nuel sacré de celui qui peut encore sauver la france du chaos qui s’est instal

# %%
# Une autre méthode "concordance" : montre les occurences d'un mot dans son contexte
print("Exemples d'occurences du terme 'vérité' :")
text2.concordance("raison")
print('\n')
# Out:
# Exemples d'occurences du terme 'vérité' :
# Displaying 2 of 2 matches:
# zemmour a raison zemour a raison sur tout il dit la
# zemmour a raison zemour a raison sur tout il dit la verite ...... un

# %%
import matplotlib.pyplot as plt

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(w_joined)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
inputs= data.groupby("Source")
inputs.describe().head()
# Out:
#         Texto
#         count unique                                                top freq
# Source
# Amazon     40     40  zemmour a raison zemour a raison sur tout il d...    1
# Twitter    33     26  rt @unvola2: cela laisse peu de doute qu’éric ...    4
